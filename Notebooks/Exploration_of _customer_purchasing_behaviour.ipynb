# %%
import sys
import os
import logging
import pandas as pd
sys.path.append(os.path.abspath('../Scripts'))
import warnings
warnings.filterwarnings('ignore')

# %%
import Eda_Custom_pb as ed

# %%
# Load the data
df = ed.load_data('../Data/Merged.csv')
Test = ed.load_data('../Data/test.csv')
Train = ed.load_data('../Data/train.csv')

# %%
Test
# Out:
#           Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# 0          1      1          4   1.0      1            0              0
# 1          2      3          4   1.0      1            0              0
# 2          3      7          4   1.0      1            0              0
# 3          4      8          4   1.0      1            0              0
# 4          5      9          4   1.0      1            0              0
# ...      ...    ...        ...   ...    ...          ...            ...
# 41072  41084   1111          6   1.0      0            0              0
# 41073  41085   1112          6   1.0      0            0              0
# 41074  41086   1113          6   1.0      0            0              0
# 41075  41087   1114          6   1.0      0            0              0
# 41076  41088   1115          6   1.0      0            0              1
#
# [41077 rows x 7 columns]

# %%
Train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %% [markdown]
# check the promo distribution between test and train dataset

# %%
Promo_dist = ed.analyze_distribution(Train, Test)
# Out:
# Training Set Promo Distribution:
# Promo
# 0    0.618485
# 1    0.381515
# Name: proportion, dtype: float64
#
# Test Set Promo Distribution:
# Promo
# 0    0.604158
# 1    0.395842
# Name: proportion, dtype: float64

# %%
ed.plot_distribution(Train, Test)

# %%
df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017203   1111          2  2013-01-01      0          0     0      0
# 1017204   1112          2  2013-01-01      0          0     0      0
# 1017205   1113          2  2013-01-01      0          0     0      0
# 1017206   1114          2  2013-01-01      0          0     0      0
# 1017207   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
df.shape
# Out:
# (1017208, 18)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017203   1111          2 2013-01-01      0          0     0      0
# 1017204   1112          2 2013-01-01      0          0     0      0
# 1017205   1113          2 2013-01-01      0          0     0      0
# 1017206   1114          2 2013-01-01      0          0     0      0
# 1017207   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %% [markdown]
# There are Variable expected that affect sales condition, The next analysis focuses on this variables

# %%
df.describe(include = 'object')
# Out:
#        StateHoliday StoreType Assortment PromoInterval
# count       1017208   1017208    1017208       1017208
# unique            5         4          3             4
# top               0         a          a             0
# freq         592942    551626     537445        508031

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
# Out:
# StateHoliday
# [0 '0' 'a' 'b' 'c']
# StoreType
# ['c' 'a' 'd' 'b']
# Assortment
# ['a' 'c' 'b']
# PromoInterval
# ['0' 'Jan,Apr,Jul,Oct' 'Feb,May,Aug,Nov' 'Mar,Jun,Sept,Dec']

# %%
import matplotlib.pyplot as plt

# %%
 df.set_index('Date', inplace=True)

# %%
ed.plot_customers_per_month(df)

# %%
# We can calculate sale per customer to compare stores correctly.
df['SalePerCustomer'] = df['Sales']/df['Customers']
df['SalePerCustomer'].describe()
# Out:
# count    844339.000000
# mean          9.493602
# std           2.197438
# min           0.000000
# 25%           7.895560
# 50%           9.250000
# 75%          10.899727
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %% [markdown]
# On average customers spend about 9.49$ per day. Though there are days with Sales equal to zero.

# %%
# Count the number of 0 values in the sales column

count_zero_sales = (df['Sales'] == 0).sum()
percentage_of_zero_sales = (count_zero_sales / 1017208) * 100
print(f"percentage_of_zero_sales= :{percentage_of_zero_sales}")
print(f"count_zero_sales=: {count_zero_sales}")
# Out:
# percentage_of_zero_sales= :16.994655960236255
# count_zero_sales=: 172871

# %% [markdown]
# About 17% of data has zero amount of saless. is it only due to the fact that the store is closed?

# %%
# check Days open with no sales
print(df[(df.Open == 1) & (df.Sales == 0)].shape)
# Out:
# (54, 19)

# %% [markdown]
# There're only 54 days in the data with no sales at all on Working days, So there might be another factors

# %%
ed.plot_sales_per_month(df)

# %%
ed.add_holiday_column(df)
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017203   1111          2 2013-01-01      0          0     0      0
# 1017204   1112          2 2013-01-01      0          0     0      0
# 1017205   1113          2 2013-01-01      0          0     0      0
# 1017206   1114          2 2013-01-01      0          0     0      0
# 1017207   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 0                  0              1         c  ...              1270.0
# ...

# %% [markdown]
# Store Type performance on sales

# %%
df.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std  min     25%     50%       75%  \
# StoreType
# a          551626.0   5738.114788  3963.738447  0.0  3508.0  5618.0   7860.00
# b           15830.0  10058.837334  5280.525506  0.0  6227.0  9025.5  13082.75
# c          136840.0   5723.629246  3721.700886  0.0  3789.0  5766.0   7849.00
# d          312912.0   5641.819243  3473.393781  0.0  3986.0  5826.0   7691.00
#
#                max
# StoreType
# a          38025.0
# b          38722.0
# c          31448.0
# d          38037.0

# %% [markdown]
# B has Highest average sales but less data, what is the reason?

# %%
df.groupby('StoreType')[['Customers', 'Sales']].sum()
# Out:
#            Customers       Sales
# StoreType
# a          363539713  3165293308
# b           31465621   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %% [markdown]
# The most Crowded Store is Store Type A also with the highest sales among other sales type<br>The least crowded and small sales Store is store Type B, Customer and Sales might ahve direct Proportionality

# %%
columns_for_correlation = ['Sales', 'Customers']

# Filter the DataFrame to keep these columns
correlation_df = df[columns_for_correlation]

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()

# Display the correlation matrix
print("Correlation between Customer and Sales:")
print(correlation_matrix)
# Out:
# Correlation between Customer and Sales:
#              Sales  Customers
# Sales      1.00000    0.89473
# Customers  0.89473    1.00000

# %% [markdown]
# It is Cleare That both Sales and Customers are highly correlated.

# %%
import datetime

# %%
ed.plot_day_of_week_sales(df)

# %% [markdown]
#  All Type of Store are Closed on Sunday Except B, this additional day of the week Might be the reason for B to have high average sales . here there must be clear insight of customer behaviour on open and closed Days

# %% [markdown]
# All plots show us  that there in cleare incressing of sales in christmas, So there might be relationship between sales or customer flow in season of holidays

# %%
ed.plot_holiday_sales_distribution(df)

# %%
ed.plot_holiday_effect(df)

# %% [markdown]
# AS shown  Holidays and sales doesnt have much relationship

# %%
ed.custom_behaviour_during_open_and_close(df)

# %% [markdown]
# For the non working days no customer flow

# %% [markdown]
# # Promotion  Relation With Customer and  Sales distribution

# %%
monthly_promo_sales = df.groupby('Promo')['Sales'].mean()
print(monthly_promo_sales)
# Out:
# Promo
# 0    4405.991763
# 1    7991.152046
# Name: Sales, dtype: float64

# %%
ed.plot_promo_effect(df)

# %%
ed.plot_sales_vs_promo(df)

# %% [markdown]
# Promotion and sales are directly proportional

# %% [markdown]
# ### Competition Stores affect on the sales and flow of Customers

# %%
df.loc[:, ['StoreType', 'Sales', 'Customers', 'CompetitionDistance','CompetitionOpenSinceYear']].groupby('StoreType').max()
# Out:
#            Sales  Customers  CompetitionDistance  CompetitionOpenSinceYear
# StoreType
# a          38025       7388              75860.0                    2015.0
# b          38722       5494               3640.0                    2014.0
# c          31448       3096              45740.0                    2015.0
# d          38037       2239              48330.0                    2015.0

# %% [markdown]
# Store Type B has lower competition distance exposure than other Stores and also high average customer flows, even if the stores are in the city center ther might not be any difference in number of customer Because of high flow of populations

# %%
ed.sales_trends_over_time_by_assortment_type(df)

# %%
ed.Sales_dist_by_assortment_type(df)
